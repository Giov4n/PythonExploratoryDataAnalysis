# %% [markdown]
# # Importing Data

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
Path = r'D:\Data Analysis\01-08-2025 Instacart Basket Analysis\Data'
merged = pd.read_pickle(os.path.join(Path, 'Prepared Data', 'ord_pro_flagged.pkl'))
merged.shape
# Out:
# (32404859, 21)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 21 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   order_number            int8
#  3   order_day_of_week       int8
#  4   order_hour_of_day       int8
#  5   days_since_prior_order  float32
#  6   product_id              int32
#  7   add_to_cart_order       int16
#  8   reordered               int8
#  9   product_name            object
#  10  aisle_id                int16
#  11  department_id           int8
#  12  prices                  float32
#  13  price_range             object
#  14  busiest_days            category
#  15  busiest_period_of_day   category
#  16  max_order               int8
#  17  loyalty_flag            object
#  18  mean_price              float32
#  19  spender_type            object
#  20  orders_frequency        object
# ...

# %%
merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  3108588       1             8                  1                 14
# 1  3108588       1             8                  1                 14
# 2  3108588       1             8                  1                 14
# 3  3108588       1             8                  1                 14
# 4  3108588       1             8                  1                 14
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    14.0       12427                  1          1
# 1                    14.0         196                  2          1
# 2                    14.0       10258                  3          1
# 3                    14.0       25133                  4          1
# 4                    14.0       46149                  5          0
#
#             product_name  ...  department_id  prices  price_range  \
# ...

# %%
# Creating a bar chart
merged['order_day_of_week'].value_counts().sort_index().plot.bar(color = ['purple', 'red', 'orange'])
# Out:
# <Axes: xlabel='order_day_of_week'>

# %%
merged['prices'].plot.hist(bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Creating a scatter plot
sns.scatterplot(x='prices', y='prices', data=merged)
# Out:
# <Axes: xlabel='prices', ylabel='prices'>

# %%
# Filtering price values over 100
merged.loc[merged['prices']>100]
# Out:
#          order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 229        603376      17            22                  6                 16
# 5703       229704     342             8                  1                 19
# 10624      591140     658            30                  6                 10
# 13332      260601     846             2                  3                 11
# 13908      573149     866             4                  3                 14
# ...           ...     ...           ...                ...                ...
# 32367697   841899  204097             3                  5                 17
# 32378505  1657397  204669            12                  4                  9
# 32391862   594034  205482             1                  3                  8
# 32393899   554433  205580             9                  1                 11
# 32395238  2099090  205650             6                  1                 12
#
# ...

# %%
# Substituting values exceeding 100 with null or nan values
merged.loc[merged['prices']>100, 'prices'] = np.nan

# %%
merged['prices'].isna().sum()
# Out:
# np.int64(5127)

# %%
merged['prices'].max()
# Out:
# 25.0

# %%
# creating a histogram
hist = merged['prices'].plot.hist(bins=70)

# %%
# Saving histogram as png file
Path = r'D:\Data Analysis\01-08-2025 Instacart Basket Analysis'
hist.figure.savefig(os.path.join(Path, 'Analysis', 'Visualizations', 'hist.png'))

# %%
# Creating a list of holding True/False values to the dev np.random.rant() <= 0.7
np.random.seed(4)
dev = np.random.rand(len(merged)) <= 0.7

# %%
# Storing 70% and 30% of the sample in dataframes
big = merged[dev]
small = merged[~dev]

# %%
small.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3108588       1             8                  1                 14
# 2   3108588       1             8                  1                 14
# 3   3108588       1             8                  1                 14
# 6   1901567       2             3                  1                 10
# 10  1901567       2             3                  1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     14.0       12427                  1          1
# 2                     14.0       10258                  3          1
# 3                     14.0       25133                  4          1
# 6                      3.0       47766                  1          1
# 10                     3.0       28874                  5          0
#
#              product_name  ...  department_id  prices  price_range  \
# ...

# %%
len(merged)
# Out:
# 32404859

# %%
len(big) + len(small)
# Out:
# 32404859

# %%
# Creating data frame sample
df = small[['order_day_of_week', 'prices']]

# %%
#Creating line plot of sample data frame: small
line = sns.lineplot(x='order_day_of_week', y='prices', data=df)

# %%
line.figure.savefig(os.path.join(Path, 'Analysis', 'Visualizations', 'small_line.png'))

# %%
merged[['price_range', 'loyalty_flag', 'spender_type', 'orders_frequency']] = merged[['price_range', 'loyalty_flag', 'spender_type', 'orders_frequency']].astype('category')
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 21 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   order_number            int8
#  3   order_day_of_week       int8
#  4   order_hour_of_day       int8
#  5   days_since_prior_order  float32
#  6   product_id              int32
#  7   add_to_cart_order       int16
#  8   reordered               int8
#  9   product_name            object
#  10  aisle_id                int16
#  11  department_id           int8
#  12  prices                  float32
#  13  price_range             category
#  14  busiest_days            category
#  15  busiest_period_of_day   category
#  16  max_order               int8
#  17  loyalty_flag            category
#  18  mean_price              float32
#  19  spender_type            category
#  20  orders_frequency        category
# ...

# %%
merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  3108588       1             8                  1                 14
# 1  3108588       1             8                  1                 14
# 2  3108588       1             8                  1                 14
# 3  3108588       1             8                  1                 14
# 4  3108588       1             8                  1                 14
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    14.0       12427                  1          1
# 1                    14.0         196                  2          1
# 2                    14.0       10258                  3          1
# 3                    14.0       25133                  4          1
# 4                    14.0       46149                  5          0
#
#             product_name  ...  department_id  prices  price_range  \
# ...

# %%
merged.to_pickle(os.path.join(Path, 'Data', 'Prepared Data', 'ord_pro_4.9.pkl'))
