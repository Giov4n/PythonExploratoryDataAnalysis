# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Importing Data](#toc1_)
# - 2. [orders_products_prior.csv Data Checks](#toc2_)
# - 3. [customers.csv Data Checks](#toc3_)
#   - 3.1. [Wranging and Consistency Checks](#toc3_1_)
#   - 3.2. [Changing Data Types](#toc3_2_)
# - 4. [Combining Order_Products with Customer Data Frame](#toc4_)
# - 5. [Exporting combined data frame as a Pickle file](#toc5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[Importing Data](#toc0_)

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import os

# %%
Path = r'D:\Data Analysis\01-08-2025 Instacart Basket Analysis\Data'
df_customer = pd.read_csv(os.path.join(Path, 'Original Data', 'customers.csv'), index_col=False)
df_merged = pd.read_pickle(os.path.join(Path, 'Prepared Data', 'ord_pro_4.9.pkl'))
df_customer.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Importing orders_products_prior.csv
df_OrdProPrior = pd.read_csv(os.path.join(Path, 'Original Data', 'orders_products_prior.csv'), index_col=False)
df_OrdProPrior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %% [markdown]
# # 2. <a id='toc2_'></a>[orders_products_prior.csv Data Checks](#toc0_)

# %%
# Checking for mixed-type data with for-loop did not output any column names: none found.
for col in df_OrdProPrior.columns.tolist():
  weird = (df_OrdProPrior[[col]].map(type) != df_OrdProPrior[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_OrdProPrior[weird]) > 0:
    print (col)

# %%
# Checking for missing values
df_OrdProPrior.isna().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %% [markdown]
# There are no null values.

# %%
# Verifying if there are any duplicate values
df_OrdProPrior[df_OrdProPrior.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# Task 7. No duplicate values found in the df_OrdProPrior data frame.

# %%
df_OrdProPrior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %% [markdown]
# # 3. <a id='toc3_'></a>[customers.csv Data Checks](#toc0_)

# %% [markdown]
# ## 3.1. <a id='toc3_1_'></a>[Wranging and Consistency Checks](#toc0_)

# %%
# for-loop checking per column if dataframe contains any mixed-type columns. Weird checks wheter the datatype within columns are consistent and if stmt prints column names.
for col in df_customer.columns.tolist():
  weird = (df_customer[[col]].map(type) != df_customer[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customer[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
df_customer['First Name'].dtype
# Out:
# dtype('O')

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
#Figuring out which columns have null values
df_customer.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
#Renaming STATE column to State
df_customer.rename(columns={'STATE':'State'}, inplace=True)

# %%
#Renaming Surnam column to Surname
df_customer.rename(columns={'Surnam':'Surname'}, inplace=True)
df_customer.head()
# Out:
#    user_id First Name   Surname  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
#Creating a new variable that acts like a flag based on the missing value.
# ALt: df_cust_null = df_cust_null.loc[df_cust_null['First Name'].isna() == True]
df_cust_null = df_customer.loc[df_customer['First Name'].isnull()]
df_cust_null
# Out:
#         user_id First Name   Surname  Gender         State  Age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         n_dependants fam_status  income
# 53                 2    married   41709
# 73                 0     single   82518
# 82                 3    married  117099
# 99                 1    married  155673
# 105                3    married  151819
# ...              ...        ...     ...
# 206038             3    married   87783
# 206044             2    married  108488
# 206090             1    married   45275
# 206162             0     single   56325
# 206171             2    married   59222
#
# [11259 rows x 10 columns]

# %%
#Confirming no surname appears more than once per user id
unique = (df_cust_null.groupby('user_id')['Surname'].nunique()>1).sum()
unique
# Out:
# np.int64(0)

# %%
# Figuring out if any customer surname has a corresponding firstname in df_customer
df_customer.loc[df_customer['Surname'].isin(df_cust_null['Surname'])].sort_values(by=['First Name', 'user_id'], ascending=True)
# Out:
#         user_id First Name  Surname  Gender         State  Age date_joined  \
# 63419        29      Betty     Bean  Female  North Dakota   31  12/31/2017
# 140627       61        NaN  Fischer    Male       Florida   45   3/22/2019
# 53438        81        NaN  Sanchez    Male          Ohio   49   11/4/2017
# 30661       101        NaN    Dixon  Female     Wisconsin   58   6/27/2017
# 139882      128        NaN   Davila  Female    New Mexico   72   3/18/2019
# ...         ...        ...      ...     ...           ...  ...         ...
# 192246   206179        NaN   Dawson  Female   Mississippi   24   1/13/2020
# 126472   206181        NaN   Grimes    Male  Pennsylvania   66  12/30/2018
# 194120   206184        NaN  Gilbert    Male  South Dakota   50   1/24/2020
# 176880   206189        NaN  Simpson  Female      Virginia   75  10/16/2019
# 42671    206204        NaN  Stanley  Female       Georgia   26    9/3/2017
#
#         n_dependants        fam_status  income
# 63419              3           married   68265
# 140627             2           married  166565
# 53438              1           married  123542
# 30661              3           married  112780
# 139882             2           married  137562
# ...              ...               ...     ...
# 192246             3           married   55101
# 126472             0  divorced/widowed  135047
# 194120             1           married  163788
# 176880             2           married  156024
# 42671              2           married   47024
#
# [11260 rows x 10 columns]

# %%
#No need to impute any values since Betty Bean does not appear more than once
df_cust_null[df_cust_null['user_id']== 29]
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, Gender, State, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# Creating new data frame that doesn't include null First Names
df_cust_clean = df_customer.loc[df_customer['First Name'].isna() == False]
df_cust_clean.shape
# Out:
# (194950, 10)

# %%
# Verifying if there are any duplicate values
df_cust_clean[df_cust_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, Gender, State, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
df_cust_clean.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  194950.000000  194950.000000  194950.000000  194950.000000
# mean   103140.014947      49.511167       1.499600   94664.811495
# std     59527.705810      18.476519       1.117959   42477.262653
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51597.250000      33.000000       0.000000   59924.000000
# 50%    103091.500000      49.000000       1.000000   93572.500000
# 75%    154700.750000      66.000000       2.000000  124261.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# ## 3.2. <a id='toc3_2_'></a>[Changing Data Types](#toc0_)

# %%
df_cust_clean['user_id'] = df_cust_clean['user_id'].astype('str')
df_cust_clean[['Gender', 'fam_status']] = df_cust_clean[['Gender', 'fam_status']].astype('category')
df_cust_clean[['Age', 'n_dependants']] = df_cust_clean[['Age', 'n_dependants']].astype('int8')
df_cust_clean['income'] = df_cust_clean['income'].astype('int32')
# Out:
# C:\Users\Giova\AppData\Local\Temp\ipykernel_10404\2055568945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cust_clean['user_id'] = df_cust_clean['user_id'].astype('str')
# C:\Users\Giova\AppData\Local\Temp\ipykernel_10404\2055568945.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cust_clean[['Gender', 'fam_status']] = df_cust_clean[['Gender', 'fam_status']].astype('category')
# C:\Users\Giova\AppData\Local\Temp\ipykernel_10404\2055568945.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cust_clean[['Age', 'n_dependants']] = df_cust_clean[['Age', 'n_dependants']].astype('int8')
# C:\Users\Giova\AppData\Local\Temp\ipykernel_10404\2055568945.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cust_clean['income'] = df_cust_clean['income'].astype('int32')

# %%
df_cust_clean.head(10)
# Out:
#   user_id First Name   Surname  Gender           State  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5  133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6  152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7  168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8   69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9   82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374
# 5             2    married   49643
# 6             0     single   61746
# 7             0     single   63712
# 8             1    married  162432
# 9             2    married   32072

# %%
#Ensuring new data types did not alter the numeric values
df_cust_clean.describe()
# Out:
#                  Age   n_dependants         income
# count  194950.000000  194950.000000  194950.000000
# mean       49.511167       1.499600   94664.811495
# std        18.476519       1.117959   42477.262653
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59924.000000
# 50%        49.000000       1.000000   93572.500000
# 75%        66.000000       2.000000  124261.000000
# max        81.000000       3.000000  593901.000000

# %%
df_cust_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194950 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       194950 non-null  object
#  1   First Name    194950 non-null  object
#  2   Surname       194950 non-null  object
#  3   Gender        194950 non-null  category
#  4   State         194950 non-null  object
#  5   Age           194950 non-null  int8
#  6   date_joined   194950 non-null  object
#  7   n_dependants  194950 non-null  int8
#  8   fam_status    194950 non-null  category
#  9   income        194950 non-null  int32
# dtypes: category(2), int32(1), int8(2), object(5)
# memory usage: 10.4+ MB

# %%
#Confirming no NaN values exist in any row
df_cust_clean[df_cust_clean.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, Gender, State, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
df_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  3108588       1             8                  1                 14
# 1  3108588       1             8                  1                 14
# 2  3108588       1             8                  1                 14
# 3  3108588       1             8                  1                 14
# 4  3108588       1             8                  1                 14
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    14.0       12427                  1          1
# 1                    14.0         196                  2          1
# 2                    14.0       10258                  3          1
# 3                    14.0       25133                  4          1
# 4                    14.0       46149                  5          0
#
#             product_name  ...  department_id  prices  price_range  \
# 0    Original Beef Jerky  ...             19     4.4    Low Range
# 1                   Soda  ...              7     9.0    Mid Range
# 2             Pistachios  ...             19     3.0    Low Range
# 3  Organic String Cheese  ...             16     8.6    Mid Range
# 4      Zero Calorie Cola  ...              7    13.4    Mid Range
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag mean_price  \
# 0  Second Busiest           Most Orders        10  New Customer   6.367797
# 1  Second Busiest           Most Orders        10  New Customer   6.367797
# 2  Second Busiest           Most Orders        10  New Customer   6.367797
# 3  Second Busiest           Most Orders        10  New Customer   6.367797
# 4  Second Busiest           Most Orders        10  New Customer   6.367797
#
#    spender_type       orders_frequency
# 0   Low Spender  Non-frequent customer
# 1   Low Spender  Non-frequent customer
# 2   Low Spender  Non-frequent customer
# 3   Low Spender  Non-frequent customer
# 4   Low Spender  Non-frequent customer
#
# [5 rows x 21 columns]

# %% [markdown]
# # 4. <a id='toc4_'></a>[Combining Order_Products with Customer Data Frame](#toc0_)

# %%
# Creating a new data frame that merges all datasets
ord_pro_all = df_merged.merge(df_cust_clean, on='user_id', indicator=True)

# %%
ord_pro_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30629741 entries, 0 to 30629740
# Data columns (total 31 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   order_number            int8
#  3   order_day_of_week       int8
#  4   order_hour_of_day       int8
#  5   days_since_prior_order  float32
#  6   product_id              int32
#  7   add_to_cart_order       int16
#  8   reordered               int8
#  9   product_name            object
#  10  aisle_id                int16
#  11  department_id           int8
#  12  prices                  float32
#  13  price_range             category
#  14  busiest_days            category
#  15  busiest_period_of_day   category
#  16  max_order               int8
#  17  loyalty_flag            category
#  18  mean_price              float32
#  19  spender_type            category
#  20  orders_frequency        category
#  21  First Name              object
#  22  Surname                 object
#  23  Gender                  category
#  24  State                   object
#  25  Age                     int8
#  26  date_joined             object
#  27  n_dependants            int8
#  28  fam_status              category
#  29  income                  int32
#  30  _merge                  category
# dtypes: category(9), float32(3), int16(2), int32(2), int8(8), object(7)
# memory usage: 2.8+ GB

# %%
ord_pro_all['_merge'].value_counts()
# Out:
# _merge
# both          30629741
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
ord_pro_all = ord_pro_all.drop(columns=['_merge'])
ord_pro_all.shape
# Out:
# (30629741, 30)

# %%
# Verifying spender_type
ord_pro_all['spender_type'].value_counts(dropna=False)
# Out:
# spender_type
# Low Spender     30034178
# High Spender      595563
# Name: count, dtype: int64

# %%
# Verifying orders_frequency
ord_pro_all['orders_frequency'].value_counts(dropna=False)
# Out:
# orders_frequency
# Frequent Customer        20362711
# Regular Customer          6824080
# Non-frequent customer     3442950
# Name: count, dtype: int64

# %% [markdown]
# # 5. <a id='toc5_'></a>[Exporting combined data frame as a Pickle file](#toc0_)

# %%
ord_pro_all.to_pickle(os.path.join(Path, 'Prepared Data', 'ord_pro_cust.pkl'))
