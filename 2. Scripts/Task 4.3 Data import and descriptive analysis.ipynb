# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Importing Data](#toc1_)
# - 2. [Describing Data](#toc2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=4
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[Importing Data](#toc0_)

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
Path = r"D:\Data Analysis\01-08-2025 Instacart Basket Analysis"

# %%
vars_list = ['order_id',	'user_id',	'order_number',	'order_dow',	'order_hour_of_day',	'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(Path, 'Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prods = pd.read_csv(os.path.join(Path, 'Data', 'Original Data', 'products.csv'), usecols=['product_name',	'aisle_id',	'department_id',	'prices'])

# %%
df_prods.head(20)
# Out:
#                                          product_name  aisle_id  \
# 0                          Chocolate Sandwich Cookies        61
# 1                                    All-Seasons Salt       104
# 2                Robust Golden Unsweetened Oolong Tea        94
# 3   Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                           Green Chile Anytime Sauce         5
# 5                                        Dry Nose Oil        11
# 6                      Pure Coconut Water With Orange        98
# 7                   Cut Russet Potatoes Steam N' Mash       116
# 8                   Light Strawberry Blueberry Yogurt       120
# 9      Sparkling Orange Juice & Prickly Pear Beverage       115
# 10                                  Peach Mango Juice        31
# 11                         Chocolate Fudge Layer Cake       119
# 12                                  Saline Nasal Mist        11
# 13                     Fresh Scent Dishwasher Cleaner        74
# ...

# %%
df_prods.tail(35)
# Out:
#                                             product_name  aisle_id  \
# 49658                   Teriyaki Sauce, Sesame, Original         5
# 49659                                        Apple Cider        98
# 49660                         Masada Kosher Pocket Bread       128
# 49661                                  Cabernet Tomatoes        83
# 49662                         Brie with Herbs Foil Wedge         2
# 49663                            Organic Creamed Coconut        17
# 49664                        Professionals Sleek Shampoo        22
# 49665                                              Porto       134
# 49666                       Bacon Cheddar Pretzel Pieces       107
# 49667  Ultra Protein Power Crunch Peanut Butter N' Ho...        57
# 49668                     Lemon Cayenne Drinking Vinegar       100
# 49669      Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670                      Ginger Snaps Snacking Cookies        61
# ...

# %% [markdown]
# # 2. <a id='toc2_'></a>[Describing Data](#toc0_)

# %%
df_prods.columns
# Out:
# Index(['product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
df_prods.shape
# Out:
# (49693, 4)

# %%
df_prods.describe()
# Out:
#            aisle_id  department_id        prices
# count  49693.000000   49693.000000  49693.000000
# mean      67.770249      11.728433      9.994136
# std       38.316774       5.850282    453.519686
# min        1.000000       1.000000      1.000000
# 25%       35.000000       7.000000      4.100000
# 50%       69.000000      13.000000      7.100000
# 75%      100.000000      17.000000     11.200000
# max      134.000000      21.000000  99999.000000

# %% [markdown]
# ##### Answer: The maximum value of the aisle_id column is 134

# %%
df_prods.dtypes
# Out:
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %% [markdown]
# ##### Answer: The data type of the department_id is integer 64 bit
